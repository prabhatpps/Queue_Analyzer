# %% [markdown]
# # Step 1: Setting up Yolov8

# %% [markdown]
# First, we’ll need to install the Ultralytics package using the following command.

# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in d:\camera_vision\.venv\lib\site-packages (8.1.23)
# Requirement already satisfied: matplotlib>=3.3.0 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (3.8.3)
# Requirement already satisfied: opencv-python>=4.6.0 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (10.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (1.12.0)
# Requirement already satisfied: torch>=1.8.0 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (2.2.1)
# Requirement already satisfied: torchvision>=0.9.0 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (0.17.1)
# Requirement already satisfied: tqdm>=4.64.0 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: py-cpuinfo in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (2.2.1)
# Requirement already satisfied: seaborn>=0.11.0 in d:\camera_vision\.venv\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\camera_vision\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\camera_vision\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\camera_vision\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\camera_vision\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in d:\camera_vision\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\camera_vision\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\camera_vision\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\camera_vision\.venv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\camera_vision\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\camera_vision\.venv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\camera_vision\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\camera_vision\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\camera_vision\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\camera_vision\.venv\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in d:\camera_vision\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\camera_vision\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.10.0)
# Requirement already satisfied: sympy in d:\camera_vision\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in d:\camera_vision\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in d:\camera_vision\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.3)
# Requirement already satisfied: fsspec in d:\camera_vision\.venv\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.2.0)
# Requirement already satisfied: colorama in d:\camera_vision\.venv\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in d:\camera_vision\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\camera_vision\.venv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in d:\camera_vision\.venv\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %% [markdown]
# Then, we will import the necessary libraries and install the Yolov8 model to our local system.

# %%
# import ultralytics
from ultralytics import YOLO

# Configure the tracking parameters and run the tracker
model = YOLO('yolov8n.pt')

# %%
# !nvidia-smi
# Out:
# Thu Mar 14 21:51:48 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 551.76                 Driver Version: 551.76         CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   43C    P8              5W /   30W |       0MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Step 2: Defining Queue lines

# %% [markdown]
# Here we use the [polygonzone](https://roboflow.github.io/polygonzone/) website, that is developed by [roboflow](https://www.bing.com/search?q=roboflow&cvid=9bf5f509043f4ee89e6e3ccb83a5b8c6&gs_lcrp=EgZjaHJvbWUqBAgBEAAyBggAEEUYPDIECAEQADIECAIQADIECAMQADIECAQQADIECAUQADIGCAYQRRg8MgYIBxBFGDwyBggIEEUYPNIBCDQ1NjNqMGo0qAIAsAIA&FORM=ANAB01&PC=U531), to get the coordinates of the queue lines of our retail store. To draw the polygon make sure the mode is Polygon and then start from a point draw the required shape and end back to the same point.After this the coordinates will be reflected in the box beside from where you can copy and use it as your ROI.

# %% [markdown]
# ![Image Description](other/Picture1.png)

# %% [markdown]
# Now, let’s go through a sample implementation to see how object tracking would work for retail queue monitoring.

# %% [markdown]
# # Step 3: Setting Up YOLOv8 and Video Processing

# %% [markdown]
# In this portion of code, we set up the components required for object tracking and data gathering. Loading the YOLOv8 model, opening a video clip, establishing areas of interest (ROI), and building data structures for tracking and time recording are all part of this process. We're also setting up a CSV file and writer, as well as frame counts for video processing. This code serves as the foundation for our data collection and object tracking duties.

# %%
import cv2
import numpy as np
from ultralytics import YOLO
import csv

# Load the YOLOv8 model
model = YOLO("yolov8n.pt")

# Open the video file
video_path = "Videos/Shopping, People, Commerce, Mall, Many, Crowd, Walking   Free Stock video footage   YouTube.mp4"
cap = cv2.VideoCapture(video_path)

fps = 20

# Define the output video path
output_video_path = "/Videos/Output/output.mp4"

# Define the codec and create a VideoWriter object for the output video
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, 25.0, (frame_width, frame_height))

# Define ROI (Region of Interest) coordinates for the rectangular regions
roi1_coords = np.array([[747, 622],[707, 38],[807, 22],[931, 654],[747, 622]], dtype=np.int32)

roi2_coords = np.array([[1039, 62],[1243, 546],[1271, 502],[1231, 286],[1107, 34],[1039, 62]], dtype=np.int32)

people_enter_queue = {}
timespent = []

filename = "queue_time.csv"

# Open the file in write mode
file = open(filename, 'w', newline='')

# Create a CSV writer object
csv_writer = csv.writer(file)

frame_count =0

# %% [markdown]
# # Step 4:Video processing Loop

# %% [markdown]
# We're going into the video frames in this section of the code, keeping a careful eye on specific areas of interest. We want to detect and track items within these regions that are most likely individuals as they move through the frame. We're tracking when individuals enter and exit these places, as well as the time they spend waiting in queue.

# %%
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        annotated_frame = frame.copy()

        # Draw the ROIs
        cv2.drawContours(annotated_frame, [roi1_coords], -1, (255, 0, 0), 3)
        cv2.drawContours(annotated_frame, [roi2_coords], -1, (255, 0, 0), 3)

        # Run YOLOv8 tracking on the original frame
        results = model.track(frame, persist=True)

        # Get the boxes and track IDs
        boxes = results[0].boxes.xyxy.cpu()

        print("Found: ", people_enter_queue)

        if results[0].boxes.id is not None:
            track_ids = results[0].boxes.id.int().cpu().tolist()

            # Check if the center of bounding boxes is inside the ROI
            for box, track_id in zip(boxes, track_ids):
                print("Tracking:", track_id)

                x1, y1, x2, y2 = box
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

                x = (x1 + x2) / 2
                y = (y1 + y2) / 2

                # Visualize the people being tracked in queues on the frame
                if ((cv2.pointPolygonTest(roi1_coords, (x, y), False) > 0) or (
                        (cv2.pointPolygonTest(roi2_coords, (x, y), False)) > 0)):
                    if str(track_id) not in people_enter_queue:
                        # Get timestamp
                        people_enter_queue[str(track_id)] = str(frame_count)

                    cv2.rectangle(annotated_frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    cv2.putText(annotated_frame, "Person id:" + str(track_id), (x1, y1 - 5),
                                cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (20, 255, 0), 2)
                else:
                    print("outside:", track_id)

                    if str(track_id) in people_enter_queue:
                        # Get timestamp
                        exit = frame_count

                        # Get first timestamp
                        start = people_enter_queue[str(track_id)]

                        time_spent = (exit - int(start)) / fps
                        print("time spent ", time_spent, "by person", track_id)

                        timespent.append(time_spent)

                        # Write string to the file
                        csv_writer.writerow(["Time spent by person " + str(track_id) + " in line is " + str(time_spent)])

                        people_enter_queue.pop(str(track_id))

        # Write the frame to the output video
        out.write(annotated_frame)
        frame_count += 1

    else:
        # Break the loop if there are no more frames
        break
# Out:
# 0: 384x640 13 persons, 1 bird, 99.7ms
# Speed: 4.9ms preprocess, 99.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# 0: 384x640 13 persons, 1 bird, 103.2ms
# Speed: 3.3ms preprocess, 103.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# 0: 384x640 15 persons, 1 bird, 95.2ms
# Speed: 2.3ms preprocess, 95.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# 0: 384x640 16 persons, 1 bird, 94.5ms
# Speed: 2.2ms preprocess, 94.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# 0: 384x640 15 persons, 2 birds, 93.5ms
# Speed: 1.5ms preprocess, 93.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# 0: 384x640 17 persons, 1 bird, 91.4ms
# Speed: 2.4ms preprocess, 91.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# 0: 384x640 17 persons, 1 bird, 96.1ms
# Speed: 2.2ms preprocess, 96.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# 0: 384x640 18 persons, 1 bird, 100.4ms
# Speed: 2.0ms preprocess, 100.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# 0: 384x640 18 persons, 1 bird, 101.1ms
# Speed: 2.6ms preprocess, 101.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# 0: 384x640 18 persons, 1 bird, 104.9ms
# Speed: 2.3ms preprocess, 104.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# 0: 384x640 19 persons, 1 bird, 95.3ms
# Speed: 2.3ms preprocess, 95.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# 0: 384x640 18 persons, 2 birds, 113.9ms
# Speed: 2.8ms preprocess, 113.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# 0: 384x640 19 persons, 1 bird, 97.0ms
# Speed: 2.4ms preprocess, 97.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# 0: 384x640 20 persons, 1 bird, 95.9ms
# Speed: 2.7ms preprocess, 95.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# outside: 22
# 0: 384x640 19 persons, 2 birds, 93.3ms
# Speed: 2.2ms preprocess, 93.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# outside: 22
# 0: 384x640 19 persons, 2 birds, 98.0ms
# Speed: 2.4ms preprocess, 98.0ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# outside: 22
# 0: 384x640 20 persons, 1 bird, 104.5ms
# Speed: 2.2ms preprocess, 104.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# outside: 22
# 0: 384x640 20 persons, 1 bird, 101.2ms
# Speed: 2.3ms preprocess, 101.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 20 persons, 1 bird, 94.0ms
# Speed: 2.2ms preprocess, 94.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 20 persons, 1 bird, 94.5ms
# Speed: 2.2ms preprocess, 94.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 20 persons, 1 bird, 95.7ms
# Speed: 2.2ms preprocess, 95.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17', '5': '19'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 19 persons, 1 bird, 1 dog, 99.2ms
# Speed: 2.1ms preprocess, 99.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17', '5': '19'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 20 persons, 1 bird, 97.1ms
# Speed: 2.3ms preprocess, 97.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17', '5': '19'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 21 persons, 99.5ms
# Speed: 1.2ms preprocess, 99.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17', '5': '19'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 20 persons, 1 bird, 93.9ms
# Speed: 2.3ms preprocess, 93.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17', '5': '19'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 20 persons, 1 bird, 93.9ms
# Speed: 2.6ms preprocess, 93.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17', '5': '19'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# outside: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 21 persons, 96.2ms
# Speed: 2.3ms preprocess, 96.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17', '5': '19'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 21 persons, 99.7ms
# Speed: 2.2ms preprocess, 99.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17', '5': '19', '11': '26'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# 0: 384x640 21 persons, 97.0ms
# Speed: 2.3ms preprocess, 97.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '22': '17', '5': '19', '11': '26'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# outside: 22
# time spent  0.55 by person 22
# 0: 384x640 22 persons, 96.6ms
# Speed: 2.2ms preprocess, 96.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# 0: 384x640 21 persons, 1 bird, 95.1ms
# Speed: 2.4ms preprocess, 95.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# 0: 384x640 21 persons, 1 bird, 96.6ms
# Speed: 1.5ms preprocess, 96.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# 0: 384x640 21 persons, 1 bird, 98.0ms
# Speed: 1.2ms preprocess, 98.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# 0: 384x640 21 persons, 1 bird, 96.5ms
# Speed: 2.3ms preprocess, 96.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# 0: 384x640 21 persons, 1 bird, 97.6ms
# Speed: 3.4ms preprocess, 97.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# 0: 384x640 21 persons, 1 bird, 99.8ms
# Speed: 3.3ms preprocess, 99.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# 0: 384x640 21 persons, 1 bird, 93.9ms
# Speed: 2.2ms preprocess, 93.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# 0: 384x640 22 persons, 94.3ms
# Speed: 2.3ms preprocess, 94.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# 0: 384x640 23 persons, 99.9ms
# Speed: 1.1ms preprocess, 99.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# 0: 384x640 23 persons, 88.2ms
# Speed: 2.5ms preprocess, 88.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# 0: 384x640 22 persons, 1 bird, 105.3ms
# Speed: 2.2ms preprocess, 105.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# 0: 384x640 21 persons, 2 birds, 110.6ms
# Speed: 2.4ms preprocess, 110.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# 0: 384x640 21 persons, 2 birds, 114.6ms
# Speed: 2.3ms preprocess, 114.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# 0: 384x640 21 persons, 2 birds, 96.7ms
# Speed: 2.4ms preprocess, 96.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# 0: 384x640 22 persons, 1 bird, 95.1ms
# Speed: 2.5ms preprocess, 95.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# 0: 384x640 21 persons, 1 bird, 1 kite, 95.0ms
# Speed: 2.2ms preprocess, 95.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# 0: 384x640 22 persons, 1 bird, 106.8ms
# Speed: 2.2ms preprocess, 106.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# 0: 384x640 23 persons, 1 bird, 94.5ms
# Speed: 1.7ms preprocess, 94.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# 0: 384x640 23 persons, 1 bird, 95.9ms
# Speed: 1.1ms preprocess, 95.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# 0: 384x640 22 persons, 1 bird, 1 dog, 93.8ms
# Speed: 1.1ms preprocess, 93.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# 0: 384x640 22 persons, 1 bird, 1 dog, 95.5ms
# Speed: 2.3ms preprocess, 95.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# 0: 384x640 24 persons, 1 bird, 96.6ms
# Speed: 2.3ms preprocess, 96.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# 0: 384x640 23 persons, 1 bird, 1 dog, 96.4ms
# Speed: 2.2ms preprocess, 96.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# 0: 384x640 23 persons, 1 bird, 1 dog, 97.9ms
# Speed: 2.1ms preprocess, 97.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# 0: 384x640 23 persons, 1 bird, 1 dog, 95.5ms
# Speed: 2.3ms preprocess, 95.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# 0: 384x640 24 persons, 1 dog, 93.9ms
# Speed: 2.2ms preprocess, 93.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# 0: 384x640 24 persons, 1 bird, 93.9ms
# Speed: 2.2ms preprocess, 93.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '19': '7', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# outside: 19
# time spent  2.45 by person 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# 0: 384x640 24 persons, 1 bird, 95.4ms
# Speed: 2.2ms preprocess, 95.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '5': '19', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# 0: 384x640 24 persons, 1 bird, 96.6ms
# Speed: 2.2ms preprocess, 96.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '5': '19', '11': '26', '22': '29', '19': '57'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# 0: 384x640 27 persons, 97.1ms
# Speed: 2.4ms preprocess, 97.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '5': '19', '11': '26', '22': '29', '19': '57'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# 0: 384x640 27 persons, 100.0ms
# Speed: 1.1ms preprocess, 100.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '5': '19', '11': '26', '22': '29', '19': '57', '28': '59'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# 0: 384x640 27 persons, 96.8ms
# Speed: 1.1ms preprocess, 96.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '5': '19', '11': '26', '22': '29', '19': '57', '28': '59'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# outside: 28
# time spent  0.1 by person 28
# 0: 384x640 27 persons, 94.7ms
# Speed: 2.7ms preprocess, 94.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '5': '19', '11': '26', '22': '29', '19': '57'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# outside: 28
# 0: 384x640 28 persons, 96.1ms
# Speed: 2.2ms preprocess, 96.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '5': '19', '11': '26', '22': '29', '19': '57'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# outside: 28
# Tracking: 29
# outside: 29
# 0: 384x640 28 persons, 95.7ms
# Speed: 2.3ms preprocess, 95.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '5': '19', '11': '26', '22': '29', '19': '57'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# outside: 28
# Tracking: 29
# outside: 29
# 0: 384x640 28 persons, 96.3ms
# Speed: 2.6ms preprocess, 96.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '5': '19', '11': '26', '22': '29', '19': '57'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# time spent  2.3 by person 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# outside: 28
# Tracking: 29
# outside: 29
# 0: 384x640 29 persons, 96.3ms
# Speed: 3.6ms preprocess, 96.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '11': '26', '22': '29', '19': '57'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# outside: 28
# Tracking: 29
# outside: 29
# Tracking: 30
# outside: 30
# 0: 384x640 28 persons, 1 dog, 95.0ms
# Speed: 2.3ms preprocess, 95.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '11': '26', '22': '29', '19': '57'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 15
# outside: 15
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# outside: 28
# Tracking: 29
# outside: 29
# Tracking: 30
# outside: 30
# 0: 384x640 27 persons, 1 dog, 99.5ms
# Speed: 2.3ms preprocess, 99.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '11': '26', '22': '29', '19': '57'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# outside: 19
# time spent  0.55 by person 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# outside: 28
# Tracking: 29
# outside: 29
# Tracking: 30
# outside: 30
# 0: 384x640 28 persons, 95.0ms
# Speed: 2.3ms preprocess, 95.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'6': '0', '9': '0', '12': '0', '11': '26', '22': '29'}
# Tracking: 1
# outside: 1
# Tracking: 2
# outside: 2
# Tracking: 3
# outside: 3
# Tracking: 4
# outside: 4
# Tracking: 5
# outside: 5
# Tracking: 6
# Tracking: 7
# outside: 7
# Tracking: 8
# outside: 8
# Tracking: 9
# Tracking: 10
# outside: 10
# Tracking: 11
# Tracking: 12
# Tracking: 13
# outside: 13
# Tracking: 14
# outside: 14
# Tracking: 16
# outside: 16
# Tracking: 17
# outside: 17
# Tracking: 18
# outside: 18
# Tracking: 19
# outside: 19
# Tracking: 20
# outside: 20
# Tracking: 22
# Tracking: 23
# outside: 23
# Tracking: 24
# outside: 24
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 27
# outside: 27
# Tracking: 28
# outside: 28
# Tracking: 29
# outside: 29
# Tracking: 30
# outside: 30
# 0: 384x640 28 persons, 1 dog, 98.5ms
# ...
# Tracking: 12
# outside: 12
# Tracking: 25
# outside: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# 0: 384x640 23 persons, 95.9ms
# Speed: 2.1ms preprocess, 95.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318'}
# Tracking: 12
# outside: 12
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# 0: 384x640 23 persons, 92.2ms
# Speed: 2.6ms preprocess, 92.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 12
# outside: 12
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# 0: 384x640 22 persons, 94.1ms
# Speed: 1.2ms preprocess, 94.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# 0: 384x640 22 persons, 99.5ms
# Speed: 2.5ms preprocess, 99.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# 0: 384x640 24 persons, 102.7ms
# Speed: 3.6ms preprocess, 102.7ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 58
# outside: 58
# 0: 384x640 25 persons, 93.6ms
# Speed: 2.7ms preprocess, 93.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 58
# outside: 58
# Tracking: 43
# outside: 43
# 0: 384x640 25 persons, 91.7ms
# Speed: 2.2ms preprocess, 91.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 58
# outside: 58
# Tracking: 43
# outside: 43
# 0: 384x640 25 persons, 1 umbrella, 86.3ms
# Speed: 3.6ms preprocess, 86.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 58
# outside: 58
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# 0: 384x640 25 persons, 1 umbrella, 100.5ms
# Speed: 2.3ms preprocess, 100.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 58
# outside: 58
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# 0: 384x640 25 persons, 90.2ms
# Speed: 1.3ms preprocess, 90.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# 0: 384x640 25 persons, 90.2ms
# Speed: 2.2ms preprocess, 90.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# 0: 384x640 25 persons, 101.6ms
# Speed: 2.1ms preprocess, 101.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# 0: 384x640 24 persons, 1 bird, 99.2ms
# Speed: 2.3ms preprocess, 99.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# 0: 384x640 26 persons, 97.5ms
# Speed: 2.3ms preprocess, 97.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# Tracking: 58
# outside: 58
# 0: 384x640 26 persons, 110.5ms
# Speed: 2.2ms preprocess, 110.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 35
# outside: 35
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# Tracking: 58
# outside: 58
# 0: 384x640 25 persons, 95.4ms
# Speed: 2.2ms preprocess, 95.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# Tracking: 60
# outside: 60
# 0: 384x640 24 persons, 1 bird, 101.0ms
# Speed: 2.7ms preprocess, 101.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 45
# outside: 45
# Tracking: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# Tracking: 60
# outside: 60
# 0: 384x640 25 persons, 90.6ms
# Speed: 2.5ms preprocess, 90.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '29': '147', '46': '301', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# outside: 29
# time spent  9.55 by person 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 45
# outside: 45
# Tracking: 46
# outside: 46
# time spent  1.85 by person 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# Tracking: 60
# outside: 60
# 0: 384x640 25 persons, 104.4ms
# Speed: 6.3ms preprocess, 104.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# outside: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 45
# outside: 45
# Tracking: 46
# outside: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# Tracking: 60
# outside: 60
# 0: 384x640 25 persons, 106.2ms
# Speed: 2.6ms preprocess, 106.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Found:  {'9': '0', '53': '318', '25': '321'}
# Tracking: 25
# Tracking: 26
# outside: 26
# Tracking: 31
# outside: 31
# Tracking: 33
# outside: 33
# Tracking: 34
# outside: 34
# Tracking: 36
# outside: 36
# Tracking: 38
# outside: 38
# Tracking: 29
# outside: 29
# Tracking: 40
# outside: 40
# Tracking: 41
# outside: 41
# Tracking: 44
# outside: 44
# Tracking: 45
# outside: 45
# Tracking: 46
# outside: 46
# Tracking: 48
# outside: 48
# Tracking: 49
# outside: 49
# Tracking: 42
# outside: 42
# Tracking: 28
# outside: 28
# Tracking: 51
# outside: 51
# Tracking: 53
# Tracking: 54
# outside: 54
# Tracking: 55
# outside: 55
# Tracking: 57
# outside: 57
# Tracking: 43
# outside: 43
# Tracking: 59
# outside: 59
# Tracking: 60
# outside: 60

# %% [markdown]
# # Step 5: Time calculation

# %% [markdown]
# We use the formula time_spent = (exit - start) / fps in this code section to compute the time individuals spent in a queue by iterating through the people_enter_queue dictionary. We then use the formula average = sum(time spent) / len(time spent) to calculate the average time spent by all persons. When the loop is over, the program carefully handles resource release, completing video processing.

# %%
for person in people_enter_queue:
    #get timestamp
    exit = frame_count

    #get first timestamp
    start = people_enter_queue.get(person)

    time_spent = (exit - int(start))/fps
    print("time spent ", time_spent, "by person", person)

    timespent.append(time_spent)

    # Write string to the file
    csv_writer.writerow(["Time spent by person "+ str(person)+" in line is "+str(time_spent)])

    average = sum(timespent)/len(timespent)

    print("Average of list: ", round(average,3))

    csv_writer.writerow(["Average time spent in line is "+str(round(average,3))])
    # Break the loop if the end of the video is reached
    break


# Release the video capture object, release the output video, and close the display window
cap.release()
out.release()
cv2.destroyAllWindows()
file.close()

print(f"Output video saved at: {output_video_path}")
# Out:
# time spent  17.05 by person 9
# Average of list:  5.294
# Output video saved at: /Videos/Output/output.mp4

# %% [markdown]
# # Output

# %% [markdown]
# Here is the final csv file displaying the input the time spent by the person in the queue and average time.

# %% [markdown]
# ![Image Description](other/Picture2.png)

# %% [markdown]
# Here is the final tracking [video](https://drive.google.com/file/d/1pSHGDGw4_7CvKfczNPQBlKum0ixXI0b9/view?usp=drive_link)

# %% [markdown]
# ![Image Description](other/Picture3.png)

# %% [markdown]
# # Conclusion

# %% [markdown]
# This article delves into the interesting world of queue analytics via object detection. It's a fantastic chance for merchants to capitalise on the power of these advancements as they become more accessible and affordable. Consider having unprecedented insights into customer behaviour, allowing you to make data-driven decisions that improve in-store experiences. In this fiercely competitive multichannel era, using computer vision and future technologies has become a strategic essential for shops seeking to not only survive but grow.
